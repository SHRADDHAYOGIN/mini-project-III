# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/customer_final_df')
df
# Out:
#      cust_id hasCredit  numCreditTnx  creditSpendToLimitRatio hasSavings  \
# 0    1362691        No           0.0                 0.000000         No
# 1    1362487        No          32.0                 0.001168        Yes
# 2    1363160       Yes          68.0                -0.001948        Yes
# 3    1362752       Yes          15.0                 0.065904        Yes
# 4    1362548       Yes          22.0                 0.048169        Yes
# ..       ...       ...           ...                      ...        ...
# 742  1363324        No           0.0                 0.000000         No
# 743  1362895        No          27.0                -0.006428        Yes
# 744  1362569        No          28.0                -0.040529         No
# 745  1363364       Yes          75.0                -0.013960         No
# 746  1363303        No          61.0                -0.009558         No
#
#      incomeSavedOverTime  numSavingsTnx hasChecking  numCheckingTnx  \
# ...

# %%
df.drop(columns='cust_id', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   hasCredit                747 non-null    object
#  1   numCreditTnx             747 non-null    float64
#  2   creditSpendToLimitRatio  747 non-null    float64
#  3   hasSavings               747 non-null    object
#  4   incomeSavedOverTime      747 non-null    float64
#  5   numSavingsTnx            747 non-null    float64
#  6   hasChecking              747 non-null    object
#  7   numCheckingTnx           747 non-null    float64
#  8   averageCheckingTnx       747 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 52.7+ KB

# %%
df_numerical = ['numCreditTnx', 
                'creditSpendToLimitRatio', 
               'incomeSavedOverTime',
               'averageCheckingTnx']
for col in df_numerical:
    
    plt.hist(df[col], 
#              bins,
             label=col)
    plt.legend(loc='best')
    plt.show()

# %%
# box plot
for col in df_numerical:
    
    plt.boxplot(df[col])
    plt.xlabel(col)
    plt.show()

# %%
for col in ['hasCredit', 'hasSavings', 'hasChecking']:
    df[col] = df[col].apply(lambda x: 1 if x == 'Yes' else 0)
df
# Out:
#      hasCredit  numCreditTnx  creditSpendToLimitRatio  hasSavings  \
# 0            0           0.0                 0.000000           0
# 1            0          32.0                 0.001168           1
# 2            1          68.0                -0.001948           1
# 3            1          15.0                 0.065904           1
# 4            1          22.0                 0.048169           1
# ..         ...           ...                      ...         ...
# 742          0           0.0                 0.000000           0
# 743          0          27.0                -0.006428           1
# 744          0          28.0                -0.040529           0
# 745          1          75.0                -0.013960           0
# 746          0          61.0                -0.009558           0
#
#      incomeSavedOverTime  numSavingsTnx  hasChecking  numCheckingTnx  \
# 0               0.000000            0.0            0             0.0
# ...

# %%
df.to_csv('../data/model_final_df', index=False)

pd.read_csv('../data/model_final_df')
# Out:
#      hasCredit  numCreditTnx  creditSpendToLimitRatio  hasSavings  \
# 0            0           0.0                 0.000000           0
# 1            0          32.0                 0.001168           1
# 2            1          68.0                -0.001948           1
# 3            1          15.0                 0.065904           1
# 4            1          22.0                 0.048169           1
# ..         ...           ...                      ...         ...
# 742          0           0.0                 0.000000           0
# 743          0          27.0                -0.006428           1
# 744          0          28.0                -0.040529           0
# 745          1          75.0                -0.013960           0
# 746          0          61.0                -0.009558           0
#
#      incomeSavedOverTime  numSavingsTnx  hasChecking  numCheckingTnx  \
# 0               0.000000            0.0            0             0.0
# ...
